# %%
import numpy as np
import matplotlib.pyplot as plt

n_hours = 24
initial_population = 1445
pop = np.zeros(n_hours)
rate = 1.1
K = 10000000

pop[0] = initial_population
for i in range(n_hours - 1):
    pop[i + 1] = (pop[i] + pop[i] * rate * (1 - pop[i]/K)) * np.random.normal(1, 0.05)
    
print(pop)
plt.plot(pop)

np.savetxt("data_exp_X.txt", pop)

n_hours = 24
initial_population = 3087
pop = np.zeros(n_hours)
rate = .7
K = 10000000

pop[0] = initial_population
for i in range(n_hours - 1):
    pop[i + 1] = (pop[i] + pop[i] * rate * (1 - pop[i]/K)) * np.random.normal(1, 0.05)
    
print(pop)
plt.plot(pop)

np.savetxt("data_exp_Y.txt", pop)
# Out:
# [1.44500000e+03 3.04224075e+03 6.69254657e+03 1.43788532e+04
#  2.81523691e+04 6.22987883e+04 1.32989134e+05 2.84235244e+05
#  6.11699055e+05 1.22866789e+06 2.34819413e+06 4.14333258e+06
#  6.30570454e+06 8.87029020e+06 1.08803157e+07 9.84758560e+06
#  9.36019763e+06 9.91143630e+06 1.08107045e+07 1.04339264e+07
#  9.53625232e+06 1.00676007e+07 9.43069879e+06 9.84801952e+06]
# [3.08700000e+03 5.08745240e+03 8.65510495e+03 1.41624212e+04
#  2.36993445e+04 4.15203819e+04 7.36736136e+04 1.20027181e+05
#  1.98402630e+05 3.04326407e+05 4.60709298e+05 7.98546758e+05
#  1.18778969e+06 1.95298774e+06 3.05192838e+06 4.60651984e+06
#  5.85608883e+06 7.92416764e+06 9.21186394e+06 1.00208929e+07
#  1.06841072e+07 1.09739209e+07 1.03470676e+07 9.84941080e+06]
